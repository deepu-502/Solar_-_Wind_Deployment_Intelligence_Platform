# %%
import pandas as pd

# Load the dataset
csv_path = '../datasets/nasa_power/nasa_power_climate_risk_indices_190_capitals_1990_2024.csv'
df = pd.read_csv(csv_path)

# Display the column names
print("Column Names:")
print(df.columns.tolist())

# %%
# Show the first 5 rows
df.head()

# %%
# Print a short summary of the solar irradiance column (solar_mean_mj)
solar_col = 'solar_mean_mj'
mean_solar = df[solar_col].mean()
print(f"Mean Solar Irradiance ({solar_col}): {mean_solar:.2f}")
